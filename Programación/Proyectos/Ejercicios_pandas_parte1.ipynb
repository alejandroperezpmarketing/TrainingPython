# %% [markdown]
# # Ejercicios sobre la librería pandas (Primera parte)

# %% [markdown]
# Carga en un dataframe de pandas el csv `alquiler-madrid-municipios.csv` en una variable que se llame `alquiler_municipios`.
#
# A continuación:
#
# * Imprime el número de filas y columnas
# * Examina las primeras y últimas filas

# %%
# Out:
# (1190, 4)
#            municipio  anyo  cuatrimestre    precio
# 0  Alcalá De Henares  2009             4  8.561386
# 1         Alcobendas  2009             4       NaN
# 2           Alcorcón  2009             4  8.792037
# 3          Alpedrete  2009             4       NaN
# 4           Aranjuez  2009             4  7.750625

# %% [markdown]
# Con el dataframe `alquiler_municipios`:
#
# * Muestra las primeras 10 filas usando `iloc`
# * Muestra las últimas 15 filas usando `iloc`

# %%
# Out:
#             municipio  anyo  cuatrimestre    precio
# 0   Alcalá De Henares  2009             4  8.561386
# 1          Alcobendas  2009             4       NaN
# 2            Alcorcón  2009             4  8.792037
# 3           Alpedrete  2009             4       NaN
# 4            Aranjuez  2009             4  7.750625
# 5       Arroyomolinos  2009             4       NaN
# 6  Boadilla Del Monte  2009             4  9.508501
# 7        Ciempozuelos  2009             4       NaN
# 8    Collado Villalba  2009             4  9.098122
# 9      Colmenar Viejo  2009             4       NaN

# %%
# Out:
#                        municipio  anyo  cuatrimestre     precio
# 1175                Navalcarnero  2018             2   9.608852
# 1176      Paracuellos Del Jarama  2018             2   8.909102
# 1177                       Parla  2018             2   7.388671
# 1178                       Pinto  2018             2   8.702994
# 1179          Pozuelo De Alarcón  2018             2  12.185832
# 1180           Rivas Vaciamadrid  2018             2   8.755782
# 1181       Rozas De Madrid (Las)  2018             2  11.615980
# 1182    San Lorenzo Del Escorial  2018             2   8.802200
# 1183  San Sebastián De Los Reyes  2018             2  11.534502
# 1184           Torrejón De Ardoz  2018             2   8.324394
# 1185                Torrelodones  2018             2  10.553534
# 1186                 Tres Cantos  2018             2  10.781348
# 1187                   Valdemoro  2018             2   7.812653
# 1188     Villanueva De La Cañada  2018             2  11.632276
# ...

# %% [markdown]
# Establece el valor del índice a la columna `municipio`. Queremos mantener la columna `municipio` también como dato, por lo que añade la opción `drop=False` en la función `set_index`. Comprueba que el resultado es correcto mostrando las primeras filas del dataframe.

# %%
# Out:
#                            municipio  anyo  cuatrimestre    precio
# municipio
# Alcalá De Henares  Alcalá De Henares  2009             4  8.561386
# Alcobendas                Alcobendas  2009             4       NaN
# Alcorcón                    Alcorcón  2009             4  8.792037
# Alpedrete                  Alpedrete  2009             4       NaN
# Aranjuez                    Aranjuez  2009             4  7.750625

# %% [markdown]
# Muestra todos los datos disponibles del municipio de Colmenar Viejo

# %%
# Out:
#                      municipio  anyo  cuatrimestre    precio
# municipio
# Colmenar Viejo  Colmenar Viejo  2009             4       NaN
# Colmenar Viejo  Colmenar Viejo  2010             1  8.456364
# Colmenar Viejo  Colmenar Viejo  2010             2  8.643514
# Colmenar Viejo  Colmenar Viejo  2010             3  8.536332
# Colmenar Viejo  Colmenar Viejo  2010             4  8.217111
# Colmenar Viejo  Colmenar Viejo  2011             1  7.715588
# Colmenar Viejo  Colmenar Viejo  2011             2  8.438373
# Colmenar Viejo  Colmenar Viejo  2011             3  8.325827
# Colmenar Viejo  Colmenar Viejo  2011             4  8.397992
# Colmenar Viejo  Colmenar Viejo  2012             1  8.274911
# Colmenar Viejo  Colmenar Viejo  2012             2  8.498735
# Colmenar Viejo  Colmenar Viejo  2012             3  8.278263
# Colmenar Viejo  Colmenar Viejo  2012             4  8.070918
# Colmenar Viejo  Colmenar Viejo  2013             1  7.667956
# ...

# %% [markdown]
# Muestra los datos disponibles del municipio de Torrelodones para el año 2012.

# %%
# Out:
#                  municipio  anyo  cuatrimestre    precio
# municipio
# Torrelodones  Torrelodones  2012             1       NaN
# Torrelodones  Torrelodones  2012             2  8.592391
# Torrelodones  Torrelodones  2012             3  8.510168
# Torrelodones  Torrelodones  2012             4  8.721770

# %% [markdown]
# Extrae los datos de los municipios cuyo precio por metro cuadrado es superior a 13€

# %%
# Out:
#                                  municipio  anyo  cuatrimestre     precio
# municipio
# La Moraleja                    La Moraleja  2010             1  15.389614
# La Moraleja                    La Moraleja  2010             2  15.110387
# La Moraleja                    La Moraleja  2010             3  14.954535
# La Moraleja                    La Moraleja  2010             4  15.311759
# La Moraleja                    La Moraleja  2011             1  14.867768
# La Moraleja                    La Moraleja  2011             2  15.288246
# La Moraleja                    La Moraleja  2011             3  14.829012
# La Moraleja                    La Moraleja  2011             4  15.058759
# La Moraleja                    La Moraleja  2012             1  14.283536
# La Moraleja                    La Moraleja  2012             2  14.137911
# La Moraleja                    La Moraleja  2012             3  14.104371
# La Moraleja                    La Moraleja  2012             4  13.795689
# ...

# %% [markdown]
# Extrae solo los nombres de los municipios cuyo precio por metro cuadrado es superior a 15€. Para eliminar los valores duplicados, aplica la función `drop_duplicates()` al dataframe resultante.

# %%
# Out:
# municipio
# La Moraleja                      La Moraleja
# Pozuelo De Alarcón        Pozuelo De Alarcón
# Villaviciosa De Odón    Villaviciosa De Odón
# Name: municipio, dtype: object

# %% [markdown]
# Extrae los datos de los municipios cuyo precio por metro cuadrado fue inferior a 10€ entre los años 2007 y 2010, ambos inclusive

# %%
# Out:
#                                              municipio  anyo  cuatrimestre  \
# municipio
# Alcalá De Henares                    Alcalá De Henares  2009             4
# Alcorcón                                      Alcorcón  2009             4
# Aranjuez                                      Aranjuez  2009             4
# Boadilla Del Monte                  Boadilla Del Monte  2009             4
# Collado Villalba                      Collado Villalba  2009             4
# ...                                                ...   ...           ...
# San Lorenzo Del Escorial      San Lorenzo Del Escorial  2010             4
# San Sebastián De Los Reyes  San Sebastián De Los Reyes  2010             4
# Torrejón De Ardoz                    Torrejón De Ardoz  2010             4
# Tres Cantos                                Tres Cantos  2010             4
# Valdemoro                                    Valdemoro  2010             4
#
#                               precio
# municipio
# ...

# %% [markdown]
# Extrae de mayor a menor por precio las filas de la tabla para el municipio de Valdemoro a partir del año 2015.

# %%
# Out:
#            municipio  anyo  cuatrimestre    precio
# municipio
# Valdemoro  Valdemoro  2017             4  8.569180
# Valdemoro  Valdemoro  2017             3  8.444421
# Valdemoro  Valdemoro  2016             3  8.127911
# Valdemoro  Valdemoro  2018             1  8.103678
# Valdemoro  Valdemoro  2017             2  7.999722
# Valdemoro  Valdemoro  2016             4  7.838977
# Valdemoro  Valdemoro  2018             2  7.812653
# Valdemoro  Valdemoro  2017             1  7.755526
# Valdemoro  Valdemoro  2016             2  7.540234
# Valdemoro  Valdemoro  2016             1  7.447696
