# %% [markdown]
# # Ejercicios sobre la librería pandas (Segunda parte)

# %% [markdown]
# Carga en un dataframe de pandas el csv `alquiler-madrid-municipios.csv` en una variable que se llame `alquiler_municipios`.

# %%
# Out:
#            municipio  anyo  cuatrimestre    precio
# 0  Alcalá De Henares  2009             4  8.561386
# 1         Alcobendas  2009             4       NaN
# 2           Alcorcón  2009             4  8.792037
# 3          Alpedrete  2009             4       NaN
# 4           Aranjuez  2009             4  7.750625

# %% [markdown]
# Muestra un resumen estadístico de los datos en este dataframe

# %%
# Out:
#               anyo  cuatrimestre       precio
# count  1190.000000   1190.000000  1082.000000
# mean   2013.628571      2.485714     8.444801
# std       2.554343      1.131124     1.822094
# min    2009.000000      1.000000     5.187200
# 25%    2011.000000      1.000000     7.175489
# 50%    2014.000000      2.000000     8.125498
# 75%    2016.000000      4.000000     9.392417
# max    2018.000000      4.000000    15.722192

# %% [markdown]
# Extrae el precio máximo histórico para cada municipio

# %%
# Out:
# municipio
# Alcalá De Henares              9.495094
# Alcobendas                    11.310158
# Alcorcón                       9.454526
# Alpedrete                      8.705219
# Aranjuez                       7.750625
# Arroyomolinos                 10.470713
# Boadilla Del Monte            11.146804
# Ciempozuelos                   7.845939
# Collado Villalba               9.250284
# Colmenar Viejo                 9.074970
# Coslada                        9.759428
# Escorial (El)                  8.275860
# Fuenlabrada                    8.470171
# Galapagar                      8.266326
# Getafe                         9.858080
# La Moraleja                   15.722192
# Leganés                        9.397957
# Majadahonda                   12.718209
# Móstoles                       8.939172
# Navalcarnero                   9.608852
# Paracuellos Del Jarama         9.570622
# Parla                          7.937225
# Pinto                          8.702994
# ...

# %% [markdown]
# Extrae el precio máximo histórico para cada municipio antes del 2015.
#
# Para ello, selecciona, en primer lugar, las filas de las que quieres calcular el máximo. A continuación, agrupa y aplica la función `max`.

# %%
# Out:
# municipio
# Alcalá De Henares              8.568819
# Alcobendas                    10.271211
# Alcorcón                       9.015275
# Alpedrete                      8.612147
# Aranjuez                       7.750625
# Arroyomolinos                  6.602920
# Boadilla Del Monte            10.215237
# Ciempozuelos                   6.555088
# Collado Villalba               9.250284
# Colmenar Viejo                 8.643514
# Coslada                        8.808602
# Escorial (El)                  6.980225
# Fuenlabrada                    8.386711
# Galapagar                      8.154519
# Getafe                         8.829574
# La Moraleja                   15.389614
# Leganés                        9.397957
# Majadahonda                   11.659499
# Móstoles                       8.506922
# Navalcarnero                   6.275325
# Paracuellos Del Jarama         8.080457
# Parla                          7.937225
# Pinto                          8.567496
# ...

# %% [markdown]
# Crea un dataframe con el nombre de los municipios y el precio por metro cuadrado del primer cuatrimestre de 2014 y denomínalo alquiler_2014. Renombra la columna `precio` a `precio_2014`

# %%
# Out:
#                       municipio  precio_2014
# 578           Alcalá De Henares     7.183959
# 579                  Alcobendas     8.838637
# 580                    Alcorcón     7.164892
# 581                   Alpedrete     7.548971
# 582                    Aranjuez     5.828958
# 583               Arroyomolinos     6.062727
# 584          Boadilla Del Monte     9.057847
# 585                Ciempozuelos     6.004546
# 586            Collado Villalba     7.588327
# 587              Colmenar Viejo     7.128154
# 588                     Coslada     7.847591
# 589               Escorial (El)     6.461372
# 590                 Fuenlabrada     6.954800
# 591                   Galapagar     6.383627
# 592                      Getafe     7.273913
# 593                 La Moraleja    12.950882
# 594                     Leganés     7.756037
# 595                 Majadahonda    10.093245
# 596                    Móstoles     6.834655
# 597                Navalcarnero     5.993365
# ...

# %% [markdown]
# Crea un dataframe con el nombre de los municipios y el precio por metro cuadrado del cuarto cuatrimestre de 2017 y denomínalo alquiler_2017. Renombra la columna `precio` a `precio_2017`

# %%
# Out:
#                        municipio  precio_2017
# 1088           Alcalá De Henares     8.362102
# 1089                  Alcobendas    11.146899
# 1090                    Alcorcón     9.246162
# 1091                   Alpedrete     7.814013
# 1092                    Aranjuez     6.939687
# 1093               Arroyomolinos     9.734940
# 1094          Boadilla Del Monte    10.818847
# 1095                Ciempozuelos     6.435412
# 1096            Collado Villalba     8.545727
# 1097              Colmenar Viejo     8.338952
# 1098                     Coslada     9.509786
# 1099               Escorial (El)     7.486567
# 1100                 Fuenlabrada     7.900727
# 1101                   Galapagar     8.266326
# 1102                      Getafe     9.369161
# 1103                 La Moraleja    15.133234
# 1104                     Leganés     8.805945
# 1105                 Majadahonda    12.054615
# 1106                    Móstoles     8.832316
# ...

# %% [markdown]
# Crea un nuevo dataframe con el nombre `dif_2014_2017`, resultado de cruzar los dos anteriores. Se debe unir la información de los municipios de los que haya información de ambos años. Imprime las 5 primeras filas del nuevo dataframe

# %%
# Out:
#            municipio  precio_2014  precio_2017
# 0  Alcalá De Henares     7.183959     8.362102
# 1         Alcobendas     8.838637    11.146899
# 2           Alcorcón     7.164892     9.246162
# 3          Alpedrete     7.548971     7.814013
# 4           Aranjuez     5.828958     6.939687

# %% [markdown]
# En el dataframe `dif_2014_2017`, crea dos nuevas columnas que muestren la diferencia de precios entre el último cuatrimestre de 2017 y el primer cuatrimestre de 2014 en valor absoluto (2017-2014) y en porcentaje (2017-2014)*100/2014

# %%
# Out:
#            municipio  precio_2014  precio_2017   dif_abs    dif_por
# 0  Alcalá De Henares     7.183959     8.362102  1.178143  16.399637
# 1         Alcobendas     8.838637    11.146899  2.308262  26.115581
# 2           Alcorcón     7.164892     9.246162  2.081271  29.048180
# 3          Alpedrete     7.548971     7.814013  0.265041   3.510961
# 4           Aranjuez     5.828958     6.939687  1.110730  19.055375

# %% [markdown]
# Dibuja un gráfico de barras (`kind='bar'`) que muestre el diferencia en porcentaje para cada municipio. Modifica el tamaño de la figura como consideres conveniente para visualizar mejor los datos.

# %% [markdown]
# Modifica el gráfico anterior para que los datos aparezcan ordenados por la diferencia en porcentaje de cada municipio.
